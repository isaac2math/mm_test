# %%
from mmdet.apis import init_detector, inference_detector
# Out:
# /root/miniconda3/envs/openmm/lib/python3.8/site-packages/mmcv/__init__.py:20: UserWarning: On January 1, 2023, MMCV will release v2.0.0, in which it will remove components related to the training process and add a data transformation module. In addition, it will rename the package names mmcv to mmcv-lite and mmcv-full to mmcv. See https://github.com/open-mmlab/mmcv/blob/master/docs/en/compatibility.md for more details.
#   warnings.warn(

# %%
config_file = '/root/mm_test/yolov3_mobilenetv2_320_300e_coco.py'
checkpoint_file = '/root/mm_test/yolov3_mobilenetv2_320_300e_coco_20210719_215349-d18dff72.pth'

# %%
model = init_detector(config_file, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: /root/mm_test/yolov3_mobilenetv2_320_300e_coco_20210719_215349-d18dff72.pth

# %%
inference_detector(model, '/root/mm_test/demo/demo.jpg')
# Out:
# [array([[5.12585373e+01, 1.13285583e+02, 6.75553970e+01, 1.32951202e+02,
#          5.93441874e-02],
#         [5.45405579e+02, 1.11174110e+02, 5.58184143e+02, 1.24368614e+02,
#          5.04875444e-02],
#         [3.66085266e+02, 1.23848709e+02, 3.81959351e+02, 1.45342590e+02,
#          4.82500046e-02],
#         [4.92541924e+01, 1.18864487e+02, 6.38420906e+01, 1.42551971e+02,
#          4.66061570e-02],
#         [5.28776733e+02, 1.10966248e+02, 5.40568970e+02, 1.23878250e+02,
#          3.15298252e-02],
#         [4.50718628e+02, 1.01559525e+02, 4.62130371e+02, 1.10342270e+02,
#          2.94804052e-02],
#         [2.09121246e+02, 9.55668030e+01, 2.23537018e+02, 1.06073936e+02,
#          2.49165706e-02],
#         [3.54283997e+02, 1.14045540e+02, 3.68165649e+02, 1.26223015e+02,
#          2.38828808e-02],
#         [2.86977631e+02, 1.19912064e+02, 3.04448700e+02, 1.50395752e+02,
#          1.87905338e-02],
# ...
